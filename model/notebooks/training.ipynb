# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1789640992.039758   17229 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import pathlib

data_dir = "../data/raw/Howard-Cloud-X/train"
data_dir = pathlib.Path(data_dir).with_suffix('')

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 1087

# %%
import matplotlib.pyplot as plt
roses = list(data_dir.glob('Cumulus/*'))
j= 0
fig = plt.figure(figsize= (30, 20))
for i in roses[:3]:
    ax = fig.add_subplot(4, 4, j+1)
    img = PIL.Image.open(str(i))
    rgb_pixels = np.array(img)
    ax.imshow(rgb_pixels)
    j+=1

# %%
import matplotlib.pyplot as plt
roses = list(data_dir.glob('Stratus/*'))
j= 0
fig = plt.figure(figsize= (30, 20))
for i in roses[:3]:
    ax = fig.add_subplot(4, 4, j+1)
    img = PIL.Image.open(str(i))
    rgb_pixels = np.array(img)
    ax.imshow(rgb_pixels)
    j+=1
